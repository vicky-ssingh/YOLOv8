# %% [markdown]
# # Practical 4: Real-time Object Detection with YOLOv8 (Local Video → Annotated Video)
#
# ### Course: Computer Vision
# ### Objective:
# Run YOLOv8 on a locally stored video and generate a full annotated video with object detections.
#
# ### Tools Used:
# - Python
# - Ultralytics YOLOv8
# - OpenCV
#
# ---
# ## Beginner Guide
# This notebook is designed for beginners.
# Steps included:
# 1. Install libraries
# 2. Load YOLO model
# 3. Select local video file
# 4. Run object detection
# 5. Save annotated video
# 6. Display output

# %%
# ============================================================================
# Step 0: Install required packages
# ============================================================================

# !pip install ultralytics

from ultralytics import YOLO
import cv2
import os
from IPython.display import HTML
from base64 import b64encode

print("Ultralytics YOLOv8 ready")
# Out:
# Requirement already satisfied: ultralytics in c:\users\vicky\anaconda 2\lib\site-packages (8.4.14)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\vicky\appdata\roaming\python\python313\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\vicky\appdata\roaming\python\python313\site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (1.38.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\vicky\anaconda 2\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vicky\anaconda 2\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vicky\anaconda 2\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vicky\anaconda 2\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vicky\anaconda 2\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vicky\anaconda 2\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vicky\anaconda 2\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vicky\appdata\roaming\python\python313\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in c:\users\vicky\anaconda 2\lib\site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: six>=1.5 in c:\users\vicky\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vicky\anaconda 2\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vicky\anaconda 2\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vicky\anaconda 2\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vicky\anaconda 2\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in c:\users\vicky\anaconda 2\lib\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\vicky\anaconda 2\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\vicky\anaconda 2\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\vicky\anaconda 2\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\vicky\appdata\roaming\python\python313\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\vicky\anaconda 2\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\vicky\anaconda 2\lib\site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vicky\anaconda 2\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vicky\appdata\roaming\python\python313\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Ultralytics YOLOv8 ready

# %% [markdown]
# ## Step 1: Define local paths
# Provide the path of your local video file here.

# %%
# ========================================================================
# Step 1: Define paths
# ========================================================================

# Path to your local video (IMPORTANT: change this to your file location)
INPUT_VIDEO = "ytraffic.mp4"   

# Output annotated video path
OUTPUT_VIDEO = "annotated_output.mp4"

# Path to trained custom model (optional)
MODEL_PATH = os.path.join(
    "runs", "detect", "your_custom_model", "weights", "best.pt"
)

# %% [markdown]
# ## Step 2: Load YOLO model
# If custom trained model exists → load it
# Else → use pretrained YOLOv8

# %%
# ========================================================================
# Step 2: Load trained model (or pretrained)
# ========================================================================

if os.path.exists(MODEL_PATH):
    print(f"Loading custom model from: {MODEL_PATH}")
    model = YOLO(MODEL_PATH)
else:
    print("Custom model not found, loading pretrained yolov8n.pt")
    model = YOLO("yolov8n.pt")

print("Model loaded ✓")
# Out:
# Custom model not found, loading pretrained yolov8n.pt
# Model loaded ✓

# %% [markdown]
# ## Step 3: Run YOLOv8 on local video
# Each frame will be processed and saved into an annotated output video.

# %%
# ========================================================================
# Step 3: Run YOLOv8 and save annotated video
# ========================================================================

cap = cv2.VideoCapture(INPUT_VIDEO)

if not cap.isOpened():
    print("Error: Cannot open video file. Check the path.")
    exit()

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (width, height))

print("Running YOLOv8 on local video...")

while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video reached.")
        break

    # Run inference
    results = model(frame, verbose=False)

    # Draw bounding boxes
    annotated_frame = results[0].plot()

    # Save frame
    out.write(annotated_frame)

cap.release()
out.release()

print(f"Annotated video saved at: {OUTPUT_VIDEO}")
# Out:
# Running YOLOv8 on local video...
# End of video reached.
# Annotated video saved at: annotated_output.mp4
